# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("car_prices.csv")

df_apple = pd.read_csv("apple_quality.csv")

df_wine = pd.read_csv("winequality-red.csv")
df_salary = pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# 3                 volvo na rep/world omni  27500.0       27750.0
# 4  financial services remarketing (lease)  66000.0       67000.0
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %% [markdown]
# ## Goals of the EDA
# 1 Exploring the Data
# 2 Data Cleaning
# 3 Data Visualization
# 4 Feature Engineering

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# 3                 volvo na rep/world omni  27500.0       27750.0
# 4  financial services remarketing (lease)  66000.0       67000.0
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %%
df.head(5)
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# 3                 volvo na rep/world omni  27500.0       27750.0
# 4  financial services remarketing (lease)  66000.0       67000.0
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %%
df.tail()
# Out:
#         year    make   model         trim       body transmission  \
# 558832  2015     Kia    K900       Luxury      Sedan          NaN
# 558833  2012     Ram    2500  Power Wagon   Crew Cab    automatic
# 558834  2012     BMW      X5    xDrive35d        SUV    automatic
# 558835  2015  Nissan  Altima        2.5 S      sedan    automatic
# 558836  2014    Ford   F-150          XLT  SuperCrew    automatic
#
#                       vin state  condition  odometer   color interior  \
# 558832  knalw4d4xf6019304    in       45.0   18255.0  silver    black
# 558833  3c6td5et6cg112407    wa        5.0   54393.0   white    black
# 558834  5uxzw0c58cl668465    ca       48.0   50561.0   black    black
# 558835  1n4al3ap0fc216050    ga       38.0   16658.0   white    black
# 558836  1ftfw1et2eke87277    ca       34.0   15008.0    gray     gray
#
#                                                    seller      mmr  \
# 558832                                   avis corporation  35300.0
# 558833                                    i -5 uhlmann rv  30200.0
# 558834             financial services remarketing (lease)  29800.0
# 558835  enterprise vehicle exchange / tra / rental / t...  15100.0
# 558836                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate
# 558832       33000.0  Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)
# 558833       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=558837, step=1)

# %%
df.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
df.describe(include="all")
# Out:
#                  year    make   model    trim    body transmission        vin  \
# count   558837.000000  548536  548438  548186  545642       493485     558833
# unique            NaN      96     973    1963      87            4     550297
# top               NaN    Ford  Altima    Base   Sedan    automatic  automatic
# freq              NaN   93554   19349   55817  199437       475915         22
# mean      2010.038927     NaN     NaN     NaN     NaN          NaN        NaN
# std          3.966864     NaN     NaN     NaN     NaN          NaN        NaN
# min       1982.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 25%       2007.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 50%       2012.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 75%       2013.000000     NaN     NaN     NaN     NaN          NaN        NaN
# max       2015.000000     NaN     NaN     NaN     NaN          NaN        NaN
#
#          state      condition       odometer   color interior  \
# count   558837  547017.000000  558743.000000  558088   558088
# unique      64            NaN            NaN      46       17
# top         fl            NaN            NaN   black    black
# freq     82945            NaN            NaN  110970   244329
# mean       NaN      30.672365   68320.017767     NaN      NaN
# std        NaN      13.402832   53398.542821     NaN      NaN
# min        NaN       1.000000       1.000000     NaN      NaN
# 25%        NaN      23.000000   28371.000000     NaN      NaN
# 50%        NaN      35.000000   52254.000000     NaN      NaN
# 75%        NaN      42.000000   99109.000000     NaN      NaN
# max        NaN      49.000000  999999.000000     NaN      NaN
#
#                     seller            mmr   sellingprice  \
# count               558837  558799.000000  558825.000000
# unique               14263            NaN            NaN
# top     nissan-infiniti lt            NaN            NaN
# freq                 19693            NaN            NaN
# mean                   NaN   13769.377495   13611.358810
# std                    NaN    9679.967174    9749.501628
# min                    NaN      25.000000       1.000000
# 25%                    NaN    7100.000000    6900.000000
# 50%                    NaN   12250.000000   12100.000000
# 75%                    NaN   18300.000000   18200.000000
# max                    NaN  182000.000000  230000.000000
#
#                                        saledate
# count                                    558825
# unique                                     3766
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5334
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN

# %%
df.describe(include="all")
# Out:
#                  year    make   model    trim    body transmission        vin  \
# count   558837.000000  548536  548438  548186  545642       493485     558833
# unique            NaN      96     973    1963      87            4     550297
# top               NaN    Ford  Altima    Base   Sedan    automatic  automatic
# freq              NaN   93554   19349   55817  199437       475915         22
# mean      2010.038927     NaN     NaN     NaN     NaN          NaN        NaN
# std          3.966864     NaN     NaN     NaN     NaN          NaN        NaN
# min       1982.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 25%       2007.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 50%       2012.000000     NaN     NaN     NaN     NaN          NaN        NaN
# 75%       2013.000000     NaN     NaN     NaN     NaN          NaN        NaN
# max       2015.000000     NaN     NaN     NaN     NaN          NaN        NaN
#
#          state      condition       odometer   color interior  \
# count   558837  547017.000000  558743.000000  558088   558088
# unique      64            NaN            NaN      46       17
# top         fl            NaN            NaN   black    black
# freq     82945            NaN            NaN  110970   244329
# mean       NaN      30.672365   68320.017767     NaN      NaN
# std        NaN      13.402832   53398.542821     NaN      NaN
# min        NaN       1.000000       1.000000     NaN      NaN
# 25%        NaN      23.000000   28371.000000     NaN      NaN
# 50%        NaN      35.000000   52254.000000     NaN      NaN
# 75%        NaN      42.000000   99109.000000     NaN      NaN
# max        NaN      49.000000  999999.000000     NaN      NaN
#
#                     seller            mmr   sellingprice  \
# count               558837  558799.000000  558825.000000
# unique               14263            NaN            NaN
# top     nissan-infiniti lt            NaN            NaN
# freq                 19693            NaN            NaN
# mean                   NaN   13769.377495   13611.358810
# std                    NaN    9679.967174    9749.501628
# min                    NaN      25.000000       1.000000
# 25%                    NaN    7100.000000    6900.000000
# 50%                    NaN   12250.000000   12100.000000
# 75%                    NaN   18300.000000   18200.000000
# max                    NaN  182000.000000  230000.000000
#
#                                        saledate
# count                                    558825
# unique                                     3766
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5334
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN

# %% [markdown]
# #### Check Missing Values

# %%
df.isnull()
# Out:
#          year   make  model   trim   body  transmission    vin  state  \
# 0       False  False  False  False  False         False  False  False
# 1       False  False  False  False  False         False  False  False
# 2       False  False  False  False  False         False  False  False
# 3       False  False  False  False  False         False  False  False
# 4       False  False  False  False  False         False  False  False
# ...       ...    ...    ...    ...    ...           ...    ...    ...
# 558832  False  False  False  False  False          True  False  False
# 558833  False  False  False  False  False         False  False  False
# 558834  False  False  False  False  False         False  False  False
# 558835  False  False  False  False  False         False  False  False
# 558836  False  False  False  False  False         False  False  False
#
#         condition  odometer  color  interior  seller    mmr  sellingprice  \
# 0           False     False  False     False   False  False         False
# 1           False     False  False     False   False  False         False
# 2           False     False  False     False   False  False         False
# 3           False     False  False     False   False  False         False
# 4           False     False  False     False   False  False         False
# ...           ...       ...    ...       ...     ...    ...           ...
# 558832      False     False  False     False   False  False         False
# 558833      False     False  False     False   False  False         False
# 558834      False     False  False     False   False  False         False
# 558835      False     False  False     False   False  False         False
# 558836      False     False  False     False   False  False         False
#
#         saledate
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 558832     False
# 558833     False
# 558834     False
# 558835     False
# 558836     False
#
# [558837 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 123376

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# year             0.000000
# make             1.843292
# model            1.860829
# trim             1.905922
# body             2.361154
# transmission    11.694287
# vin              0.000716
# state            0.000000
# condition        2.115107
# odometer         0.016821
# color            0.134028
# interior         0.134028
# seller           0.000000
# mmr              0.006800
# sellingprice     0.002147
# saledate         0.002147
# dtype: float64

# %% [markdown]
# # #Unique Values

# %%
df.nunique()
# Out:
# year                34
# make                96
# model              973
# trim              1963
# body                87
# transmission         4
# vin             550297
# state               64
# condition           41
# odometer        172278
# color               46
# interior            17
# seller           14263
# mmr               1101
# sellingprice      1887
# saledate          3766
# dtype: int64

# %%
df["body"]
# Out:
# 0               SUV
# 1               SUV
# 2             Sedan
# 3             Sedan
# 4             Sedan
#             ...
# 558832        Sedan
# 558833     Crew Cab
# 558834          SUV
# 558835        sedan
# 558836    SuperCrew
# Name: body, Length: 558837, dtype: object

# %%
# unique values in the transmission column
df["transmission"].unique()
# Out:
# array(['automatic', nan, 'manual', 'Sedan', 'sedan'], dtype=object)

# %%
# unique values and their counts in the transmission column
df["transmission"].value_counts()
# Out:
# transmission
# automatic    475915
# manual        17544
# sedan            15
# Sedan            11
# Name: count, dtype: int64

# %%
df["transmission"].value_counts().index
# Out:
# Index(['automatic', 'manual', 'sedan', 'Sedan'], dtype='object', name='transmission')

# %%
df["transmission"].value_counts().values
# Out:
# array([475915,  17544,     15,     11], dtype=int64)

# %% [markdown]
# # Visualization
# Data Visualization with Seaborn and Matplotlib Libraries

# %%
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
len(df)
# Out:
# 558837

# %%
percentage_null = (df.isnull().sum()/(len(df)))*100

# %%
plt.figure(figsize=(8,4))

sns.barplot(x=percentage_null.index, y=percentage_null.values)

plt.xticks(rotation= 45)
plt.xlabel('Columns')
plt.ylabel('Percentage of the Null (%)')
plt.title('Percentage of the Null values in the columns')

plt.show()

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# year             0.000000
# make             1.843292
# model            1.860829
# trim             1.905922
# body             2.361154
# transmission    11.694287
# vin              0.000716
# state            0.000000
# condition        2.115107
# odometer         0.016821
# color            0.134028
# interior         0.134028
# seller           0.000000
# mmr              0.006800
# sellingprice     0.002147
# saledate         0.002147
# dtype: float64

# %% [markdown]
# # Distribution

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# 3                 volvo na rep/world omni  27500.0       27750.0
# 4  financial services remarketing (lease)  66000.0       67000.0
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %%
plt.figure(figsize=(16,4))

brand_counts = df["make"].value_counts()

plt.bar(brand_counts.index, brand_counts.values, color="orange")
plt.title("Distribution of The Brands")
plt.xlabel("Count")
plt.ylabel("Brands")
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
df["make"].value_counts()[:10]
# Out:
# make
# Ford         93554
# Chevrolet    60197
# Nissan       53946
# Toyota       39871
# Dodge        30710
# Honda        27206
# Hyundai      21816
# BMW          20719
# Kia          18077
# Chrysler     17276
# Name: count, dtype: int64

# %%
df["make"].value_counts()[2:10]
# Out:
# make
# Nissan      53946
# Toyota      39871
# Dodge       30710
# Honda       27206
# Hyundai     21816
# BMW         20719
# Kia         18077
# Chrysler    17276
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))

brand_counts = np.flip(df["make"].value_counts()[:10])

plt.barh(brand_counts.index, brand_counts.values, color="orange")
plt.title("Distribution of The Brands")
plt.xlabel("Count")
plt.ylabel("Brands")
plt.show()

# %% [markdown]
# # Count Plot

# %%
plt.figure(figsize=(16,4))

sns.countplot(x="year", data=df)
plt.xticks(rotation= 45)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Count of Sold Cars')
plt.show()

# %%
df["year"]
# Out:
# 0         2015
# 1         2015
# 2         2014
# 3         2015
# 4         2014
#           ...
# 558832    2015
# 558833    2012
# 558834    2012
# 558835    2015
# 558836    2014
# Name: year, Length: 558837, dtype: int64

# %%
current_year = 2024

df["age"] = current_year - df["year"] 

df[["year","age"]].head(5)
# Out:
#    year  age
# 0  2015    9
# 1  2015    9
# 2  2014   10
# 3  2015    9
# 4  2014   10

# %%
percentage_age = (df["age"].value_counts()/(len(df)))*100

# %%
#Point Plot

# %%
plt.figure(figsize=(16,4))

sns.pointplot(x=percentage_age.index, 
              y=percentage_age.values,
              color='lime')

plt.xticks(rotation= 45)
plt.grid()
plt.show()

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# 3                 volvo na rep/world omni  27500.0       27750.0
# 4  financial services remarketing (lease)  66000.0       67000.0
#
#                                   saledate  age
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    9
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    9
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)   10
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)    9
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)   10

# %% [markdown]
# ### Age VS Condition

# %%
conditions = [ ]

for age in df["age"].unique():
    condition = df[df["age"]==age]["condition"].mean()/df["condition"].max()*100 
    conditions.append(condition)

# %%
percentage_age.values
# Out:
# array([1.83085587e+01, 1.75664818e+01, 1.45069135e+01, 8.68732743e+00,
#        5.63706412e+00, 5.51949853e+00, 4.81589444e+00, 4.73930681e+00,
#        3.82830772e+00, 3.68515327e+00, 3.10323046e+00, 2.37654271e+00,
#        1.73843178e+00, 1.68868561e+00, 1.15740368e+00, 9.35335348e-01,
#        6.01785494e-01, 3.84548625e-01, 2.76645963e-01, 1.52280540e-01,
#        1.27228512e-01, 7.01456775e-02, 3.66833263e-02, 2.36204833e-02,
#        1.19891847e-02, 8.76820969e-03, 3.57886110e-03, 1.96837360e-03,
#        1.96837360e-03, 1.78943055e-03, 1.43154444e-03, 8.94715275e-04,
#        3.57886110e-04, 1.78943055e-04])

# %%
f,ax1 = plt.subplots(figsize =(15,4))

sns.pointplot(x=percentage_age.index, y=percentage_age.values, color='lime')
sns.pointplot(x=percentage_age.index, y=conditions, color='red')   

plt.text(35, 10, 'age(%)', color='lime', fontsize = 15, style = 'italic')
plt.text(35, 2, 'conditions(%)', color='red', fontsize = 15, style = 'italic')

plt.xlabel('Age', fontsize = 10,color='blue')
plt.ylabel('Percentage(%)', fontsize = 10,color='blue')

plt.title('Age  VS  Condition(%)',fontsize = 15,color='blue')
plt.grid()

plt.savefig('graph.png')  # to save the graph

plt.tight_layout()
plt.show()

# %%
#JOINT PLOT
g = sns.jointplot(df, x="age", y="sellingprice")
plt.show()

# %%
df_apple.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
g = sns.jointplot(df_apple, x="Size", y="Weight")
plt.show()

# %%
g = sns.lmplot(df, x="age", y="sellingprice")
plt.show()

# %%
g = sns.lmplot(df_apple, x="Size", y="Weight")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
#  16  age           558837 non-null  int64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 72.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
#  16  age           558837 non-null  int64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 72.5+ MB

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns
categorical_columns = df.select_dtypes(include=["object"]).columns

print("numerical_columns: ", numerical_columns)
print("\ncategorical_columns: ", categorical_columns)
# Out:
# numerical_columns:  Index(['year', 'condition', 'odometer', 'mmr', 'sellingprice', 'age'], dtype='object')
#
# categorical_columns:  Index(['make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'color', 'interior', 'seller', 'saledate'],
#       dtype='object')

# %%
df[numerical_columns].corr()
# Out:
#                   year  condition  odometer       mmr  sellingprice       age
# year          1.000000   0.340320 -0.772737  0.596631      0.586480 -1.000000
# condition     0.340320   1.000000 -0.318188  0.281415      0.321944 -0.340320
# odometer     -0.772737  -0.318188  1.000000 -0.588113     -0.582393  0.772737
# mmr           0.596631   0.281415 -0.588113  1.000000      0.983635 -0.596631
# sellingprice  0.586480   0.321944 -0.582393  0.983635      1.000000 -0.586480
# age          -1.000000  -0.340320  0.772737 -0.596631     -0.586480  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data=df[numerical_columns].corr(), annot=True)
plt.show()

# %% [markdown]
# # Scatter Matrix

# %%
pd.plotting.scatter_matrix(df[numerical_columns], alpha=0.5, figsize=(12, 8), diagonal='hist')
plt.suptitle('Scatter Matrix for Numerical Columns', y=1.02)
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(12,4))

plt.hist(df["mmr"], bins=50, color='green', alpha=0.7)
plt.title("Distribution of MMR (Estimated Market Value of the Vehicle)")
plt.ylabel("frequency")
plt.xlabel("MMR")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.hist(df["mmr"], bins=50, color='green', range=(0, 30000), alpha=0.7)
plt.title("Distribution of MMR (Estimated Market Value of the Vehicle)")
plt.ylabel("frequency")
plt.xlabel("MMR")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))

sns.histplot(df["mmr"], kde=True, bins=30, binrange=(0,30000))
plt.title("Distribution of MMR (Estimated Market Value of the Vehicle)")
plt.ylabel("frequency")
plt.xlabel("MMR")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(12,4))

sns.distplot(df[df["mmr"]<30000]["mmr"], kde=True, bins=30)
plt.title("Distribution of MMR (Estimated Market Value of the Vehicle)")
plt.ylabel("frequency")
plt.xlabel("MMR")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(numerical_columns), figsize=(20, 4))
# fig.subplots_adjust(hspace=0.1)

for i, column in enumerate(numerical_columns):
    axes[i].boxplot(df[column].dropna())
    axes[i].set_title(f'Box Plot for {column}')
    axes[i].set_ylabel(column)

plt.show()

# %% [markdown]
# # Data Cleaning

# %%
df = pd.read_csv("car_prices.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
# drop the unique value
df.drop("vin", axis = 1, inplace=True)

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns

numerical_columns
# Out:
# Index(['year', 'condition', 'odometer', 'mmr', 'sellingprice'], dtype='object')

# %%
df = df[numerical_columns]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   condition     547017 non-null  float64
#  2   odometer      558743 non-null  float64
#  3   mmr           558799 non-null  float64
#  4   sellingprice  558825 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 21.3 MB

# %%
df.head()
# Out:
#    year  condition  odometer      mmr  sellingprice
# 0  2015        5.0   16639.0  20500.0       21500.0
# 1  2015        5.0    9393.0  20800.0       21500.0
# 2  2014       45.0    1331.0  31900.0       30000.0
# 3  2015       41.0   14282.0  27500.0       27750.0
# 4  2014       43.0    2641.0  66000.0       67000.0

# %%
df.isnull().sum()
# Out:
# year                0
# condition       11820
# odometer           94
# mmr                38
# sellingprice       12
# dtype: int64

# %%
df.dropna(subset="sellingprice", inplace=True)
df.isnull().sum()
# Out:
# year                0
# condition       11820
# odometer           94
# mmr                26
# sellingprice        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Split the data into training (80%) and test (20%) sets
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

y_train = df_train["sellingprice"]
x_train = df_train.drop("sellingprice", axis = 1)

y_test = df_test["sellingprice"]
x_test = df_test.drop("sellingprice", axis = 1)

print(x_train[:3])
# Out:
#         year  condition  odometer      mmr
# 389141  2013       41.0   22762.0  11500.0
# 149033  2012       43.0   22960.0  10850.0
# 334714  2006       29.0  101535.0   7825.0

# %%
df_train.isnull().sum()
# Out:
# year               0
# condition       9459
# odometer          70
# mmr               20
# sellingprice       0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# year               0
# condition       2361
# odometer          24
# mmr                6
# sellingprice       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

simple_imputer = SimpleImputer(strategy='mean')

x_train[x_train.columns] = simple_imputer.fit_transform(x_train)
x_test[x_test.columns] = simple_imputer.transform(x_test)

# %%
x_train.head()
# Out:
#           year  condition  odometer      mmr
# 389141  2013.0       41.0   22762.0  11500.0
# 149033  2012.0       43.0   22960.0  10850.0
# 334714  2006.0       29.0  101535.0   7825.0
# 289185  2005.0       19.0  114500.0   3650.0
# 535150  2013.0       45.0   36266.0   8550.0

# %%
x_train.isnull().sum()
# Out:
# year         0
# condition    0
# odometer     0
# mmr          0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train[x_train.columns] = scaler.fit_transform(x_train)
x_test[x_test.columns] = scaler.transform(x_test)

# %%
scaler.feature_names_in_
# Out:
# array(['year', 'condition', 'odometer', 'mmr'], dtype=object)

# %%
scaler.mean_
# Out:
# array([2.01003817e+03, 3.06518244e+01, 6.83439574e+04, 1.37635364e+04])

# %%
x_train.head()
# Out:
#             year  condition  odometer       mmr
# 389141  0.746663   0.779602 -0.852435 -0.233820
# 149033  0.494568   0.930276 -0.848733 -0.300964
# 334714 -1.018005  -0.124444  0.620711 -0.613441
# 289185 -1.270100  -0.877815  0.863172 -1.044712
# 535150  0.746663   1.080951 -0.599895 -0.538550

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
x_train
# Out:
#             year  condition  odometer       mmr
# 389141  0.746663   0.779602 -0.852435 -0.233820
# 149033  0.494568   0.930276 -0.848733 -0.300964
# 334714 -1.018005  -0.124444  0.620711 -0.613441
# 289185 -1.270100  -0.877815  0.863172 -1.044712
# 535150  0.746663   1.080951 -0.599895 -0.538550
# ...          ...        ...       ...       ...
# 110268  0.998759  -2.233884 -0.809535  0.065746
# 259178 -0.513814  -0.425792  2.814806 -1.359772
# 365839  0.242473  -0.275118 -0.741986  3.102719
# 131932  0.998759   0.854939 -1.164988  0.954112
# 121958  0.746663  -1.932535 -0.895037 -0.264809
#
# [447060 rows x 4 columns]

# %%
# Training  the Linear Regression model
model = LinearRegression()
model.fit(x_train["condition"].values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(x_test["condition"].values.reshape(-1,1))
y_pred
# Out:
# array([17892.52726029, 17892.52726029, 13217.72523614, ...,
#        14152.68564097, 15321.38614701,  7140.48260475])

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 85713668.73510201

# %%
# Visualize the true labels vs predicted labels
plt.figure(figsize=(10, 4))

years = scaler.inverse_transform(x_test)[:,1]

sns.lineplot(x=years, y=y_test.values.flatten(), label='True Labels')
sns.lineplot(x=years, y=y_pred.flatten(), label='Predicted Labels')

plt.title('Linear Regression: True Labels vs Predicted Labels')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
# Train the Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)
y_pred
# Out:
# array([31102.39634496, 11985.80998213,  7298.09160419, ...,
#        10643.6259916 , 15243.56881654, 16022.05399542])

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 3137707.9323722497

# %%
# Visualize the true labels vs predicted labels
plt.figure(figsize=(10, 4))

conditions = scaler.inverse_transform(x_test)[:,1]

sns.lineplot(x=conditions, y=y_test.values.flatten(), label='True Labels')
sns.lineplot(x=conditions, y=y_pred.flatten(), label='Predicted Labels')

plt.title('Linear Regression: True Labels vs Predicted Labels')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
scaler.feature_names_in_
# Out:
# array(['year', 'condition', 'odometer', 'mmr'], dtype=object)

# %%
scaler.inverse_transform(x_test)[:,1]
# Out:
# array([49., 49., 29., ..., 33., 38.,  3.])
